# %% [markdown]
# # Day 2 课后练习册
#
# 请尽量独立完成。不会的地方先回看对应模块。

# %% [markdown]
# ## 任务 1
#
# 读入 `day2_cafe_sales.csv`，查看前 5 行。

# %%
# 在这里写

# %% [markdown]
# ## 任务 2
#
# 只保留 `day`、`weather_label`、`sales` 三列。

# %%
# 在这里写

# %% [markdown]
# ## 任务 3
#
# 筛选出周末并且营收大于等于 3000 的记录。

# %%
# 在这里写

# %% [markdown]
# ## 任务 4
#
# 按营收从高到低排序，查看前 10 条。

# %%
# 在这里写

# %% [markdown]
# ## 任务 5
#
# 按天气分组，计算平均营收，并写一句你的观察。

# %%
# 在这里写

# %% [markdown]
# ## 任务 6
#
# 自己造一个小 DataFrame，包含缺失值，并用 `fillna()` 处理。

# %%
# 在这里写

# %% [markdown]
# ## 任务 7
#
# 为原始 `df` 构造一个新列，例如 `high_sales_flag` 或 `price_level`。

# %%
# 在这里写

# %% [markdown]
# ## 任务 8（了解即可）
#
# 如果后面要训练模型，为什么不能只在同一批数据上学和测？请用自己的话写一句。

# %%
# 在这里写
