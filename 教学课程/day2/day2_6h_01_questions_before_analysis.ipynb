# %% [markdown]
# # Day 2 模块 1：从业务问题进入 Pandas 操作
#
# 昨天我们已经会看表、算平均数。
#
# 今天要继续往前走：不只看一张表，而是开始真正操作这张表。

# %%
from pathlib import Path
import pandas as pd

candidate_paths = [
    Path('day2_cafe_sales.csv'),
    Path('day2') / 'day2_cafe_sales.csv',
    Path('教学课程') / 'day2' / 'day2_cafe_sales.csv',
]
for path in candidate_paths:
    if path.exists():
        csv_path = path
        break
else:
    raise FileNotFoundError('未找到 day2_cafe_sales.csv')

df = pd.read_csv(csv_path)
print(csv_path.resolve())

# %% [markdown]
# ## 1. 老板今天会问什么
#
# 如果你是咖啡馆老板，今天可能会问：
#
# - 哪几天营收最高？
# - 只看晴天，会发生什么？
# - 只看周末，会不会更高？
# - 如果我只想看 `day` 和 `sales` 两列，怎么拿出来？
#
# 这些问题，已经不能只靠 `mean()` 一句解决了。

# %% [markdown]
# ## 2. Day 2 的关键词
#
# 今天会重点学：
#
# - 选列
# - 看行
# - 条件过滤
# - 排序
# - 分组强化
# - 简单清洗
# - 轻量特征构造

# %% [markdown]
# ## 3. 一句话目标
#
# Day 1 是“会读表”，Day 2 是“会操作表”。
