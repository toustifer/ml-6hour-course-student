# %% [markdown]
# # Day 2 课堂练习册
#
# 这本不是新课，是跟着模块 2-6 做巩固。

# %% [markdown]
# ## 练习 1：选列
#
# 请写代码，只看 `day` 和 `sales` 两列。

# %%
# 在这里写

# %% [markdown]
# ## 练习 2：过滤
#
# 请筛选出营收大于等于 3000 的记录。

# %%
# 在这里写

# %% [markdown]
# ## 练习 3：排序
#
# 请找出营收最高的前 5 天。

# %%
# 在这里写

# %% [markdown]
# ## 练习 4：分组
#
# 请计算不同天气下的平均营收。

# %%
# 在这里写

# %% [markdown]
# ## 练习 5：简单清洗
#
# 自己造一个含缺失值的小表，并用 `fillna()` 处理。

# %%
# 在这里写

# %% [markdown]
# ## 练习 6：构造特征
#
# 请为 `sales` 构造一个“是否高营收”的新列。

# %%
# 在这里写
