# %% [markdown]
# # Day 4 课堂练习册
#
# 跟着模块 1–5 巩固，不是新知识点轰炸。

# %% [markdown]
# ## 练习 1：三个指标
#
# 训一个随机森林，打印测试集 R²、MAE、RMSE。

# %%
# 在这里写

# %% [markdown]
# ## 练习 2：三模型对比
#
# 对比线性回归、决策树（深度 3）、随机森林的**测试 R²**，用表格或 print 呈现。

# %%
# 在这里写

# %% [markdown]
# ## 练习 3：交叉验证
#
# 对随机森林做 `cross_val_score`（`cv=3`, `scoring='r2'`），打印每一折和平均分。

# %%
# 在这里写

# %% [markdown]
# ## 练习 4：小网格搜索
#
# `n_estimators ∈ {50,100}`，`max_depth ∈ {4,8}`，打印最佳参数与测试 R²。

# %%
# 在这里写

# %% [markdown]
# ## 练习 5：最差 5 天
#
# 对测试集算 |预测−真实|，列出误差最大的 5 行（含部分特征列）。

# %%
# 在这里写

# %% [markdown]
# ## 练习 6：口头
#
# 1. MAE 和 RMSE 哪个对「特别离谱的一天」更敏感？
# 2. 超参数举两个例子。
# 3. 本项目默认模型是谁？一句话原因。

# %%
# 在这里写
