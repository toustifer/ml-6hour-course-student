# %% [markdown]
# # Day 4 模块 0：复习与环境自检
#
# 昨天：会训随机森林、会看特征重要性、会读测试集 R²。
#
# 今天主线：
#
# ```text
# 评估指标（R² / MAE / RMSE）
#   → 多种算法对比
#   → 交叉验证与网格搜索调参
#   → 残差：哪里猜得差
# ```
#
# 目标：能说清「模型好不好」，并理解**为什么项目里常用随机森林**。

# %% [markdown]
# ## 1. 环境自检
#
# 内核仍用 `day1_ml`。需要：`pandas`、`sklearn`、`matplotlib`。

# %%
import sys
print('Python:', sys.version.split()[0])

import pandas as pd
import sklearn
print('pandas:', pd.__version__)
print('sklearn:', sklearn.__version__)

import matplotlib
print('matplotlib:', matplotlib.__version__)
print('环境 OK')

# %% [markdown]
# ## 2. 读入今天的数据
#
# CSV 与 notebook 在同一 `day4` 目录：`day4_cafe_sales.csv`（内容与 Day 3 同一套咖啡馆数据）。

# %%
from pathlib import Path
import pandas as pd

candidate_paths = [
    Path('day4_cafe_sales.csv'),
    Path('day4') / 'day4_cafe_sales.csv',
    Path('教学课程') / 'day4' / 'day4_cafe_sales.csv',
]
for path in candidate_paths:
    if path.exists():
        csv_path = path
        break
else:
    raise FileNotFoundError('未找到 day4_cafe_sales.csv')

df = pd.read_csv(csv_path)
print(csv_path.resolve())
print('shape:', df.shape)
df.head()

# %% [markdown]
# ## 3. 30 秒口头复习（先说再写）
#
# 1. `fit` 和 `predict` 各干什么？
# 2. 为什么更要看**测试集** R²？
# 3. 特征重要性是「模型更依赖谁」，还是「一定是业务因果」？

# %%
# 可选：用一句话写下你的答案
