# %% [markdown]
# # Day 4 课后练习册
#
# 回家独立完成。数据：`day4_cafe_sales.csv`。

# %% [markdown]
# ## 任务 1
#
# 读数据 → `weather_score` → `X, y` → 划分（0.2, 42）。

# %%
# 在这里写

# %% [markdown]
# ## 任务 2
#
# 训练随机森林（可用 `n_estimators=100, max_depth=8`），报告：
#
# - 测试 R²
# - 测试 MAE
# - 测试 RMSE

# %%
# 在这里写

# %% [markdown]
# ## 任务 3
#
# 再训练线性回归与决策树（深度 3），做三行对比表：模型名、测试 R²、测试 MAE。

# %%
# 在这里写

# %% [markdown]
# ## 任务 4
#
# 用 `GridSearchCV`（网格自定但组合数 ≤ 8），给出 `best_params_` 与测试 R²。对比调参前固定参数的测试 R²。

# %%
# 在这里写

# %% [markdown]
# ## 任务 5（文字）
#
# 写 5–8 句：
#
# 1. 今天谁测试分最好？
# 2. 有没有过拟合苗头？
# 3. 若只能上线一个模型进咖啡馆网页，你选谁？为什么？

# %%
# 在这里写
