# %% [markdown]
# # Day 5 模块 6：结营路演 + 五天收束
#
# ## 1. 结营正式路演（3～5 分钟）
#
# 按模块 5 汇报卡讲；**鼓励带迷你网页 live**。
#
# 评分自己看：
#
# | 项 | 过线 |
# | --- | --- |
# | 问题清晰 | 老板听得懂你在回答什么 |
# | 至少 2 条带数字的证据 | 场景或模型 |
# | 有演示或等价 what-if | 网页 / notebook 皆可 |
# | 3 条可执行建议 | 能说如何验证 |
# | 有局限 | 不吹过头 |
#
# ## 2. 五天链条（齐读）
#
# ```text
# Day1  Python 与数据感觉
# Day2  把表切成经营场景
# Day3  树与森林：从特征猜营收
# Day4  评估、对比、调参、残差
# Day5  证据 + 给老板看的演示 + 结营
# ```
#
# ## 3. 你带走的工作流
#
# ```text
# 提问 → 取证 → 模型辅助 → 做成能演示的成果 → 建议与验证
# ```
#
# 换一个行业，链条同样用。
#
# ## 4. 自我合格线
#
# 1. 能讲 2 条场景发现（带数字）
# 2. 能训 RF，重要性用业务话说
# 3. 能启动迷你网页或清晰口述 what-if
# 4. 能完整走一遍「给老板」时间轴
# 5. 能用一句话串起五天
#
# ---
#
# ## 更完整的五天回顾结营
#
# 若下午要**带着全班把 Day1→Day5 再走一遍**（动手 + 口述），请打开：
#
# **`day5_6h_09_five_day_grand_review.ipynb`**
#
# 那本是通关回顾主本；本文件保留「短结营 + 合格线」。

# %%
items = [
    '场景证据',
    '重要性业务话',
    '网页或 what-if 演示',
    '老板汇报时间轴',
    '五天一句话',
]
for i, t in enumerate(items, 1):
    print(f'{i}. [ ] {t}')

# %% [markdown]
# ## 5. 结营寄语
#
# 技术栈是手段；**让听的人知道下一步做什么**才是终点。
# 祝贺完成本次营期。
