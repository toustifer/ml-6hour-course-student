# %% [markdown]
# # Day 5 课堂练习册
#
# 服务结营：问题、场景、模型、报告。

# %% [markdown]
# ## 练习 1：三个经营问题
#
# 写出你要回答的 3 个店长问题。

# %%
# 1. 2. 3.

# %% [markdown]
# ## 练习 2：场景对比
#
# 至少完成天气或促销的分组均值，并写一句发现。

# %%
# 代码 + 发现

# %% [markdown]
# ## 练习 3：交叉表
#
# 周末×促销的平均营收 pivot，写一句。

# %%
# 在这里写

# %% [markdown]
# ## 练习 4：重要性业务话
#
# 训 RF，列出 Top3，各用半句业务话。

# %%
# 在这里写

# %% [markdown]
# ## 练习 5：一次 what-if
#
# 只改一个条件，记录基准与新预测。

# %%
# 在这里写

# %% [markdown]
# ## 练习 6：路演 60 秒草稿
#
# 发现 + 建议 + 局限各一句。

# %%
# 在这里写
