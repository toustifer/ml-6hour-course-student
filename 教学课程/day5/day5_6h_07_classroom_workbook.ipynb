# %% [markdown]
# # Day 5 课堂练习册
#
# 服务在终端跑；本册负责记录与少量请求代码。

# %% [markdown]
# ## 练习 1：概念
#
# 用自己的话写：浏览器、Flask、随机森林各负责什么？

# %%
# 在这里写

# %% [markdown]
# ## 练习 2：Hello
#
# 启动 `hello_flask.py`（或老师指定的 Hello），访问首页，截图或写下浏览器显示的文字。

# %%
# 记录

# %% [markdown]
# ## 练习 3：迷你应用
#
# 启动 `mini_predict_app.py`，训练后记录 R²、MAE；预测一组特征，写下输入与结果。

# %%
# R2 / MAE / 预测输入 / 预测结果

# %% [markdown]
# ## 练习 4：完整系统走查
#
# 在 `system` 启动后，按 首页→数据→训练→预测 走一遍，勾选完成项。

# %%
# 完成的步骤：

# %% [markdown]
# ## 练习 5：对照
#
# 打开 `mini_predict_app.py`，标出：特征列表、fit、predict、route 各在哪一类代码附近（行号或函数名）。

# %%
# 在这里写

# %% [markdown]
# ## 练习 6：口头
#
# 1. GET 和 POST 今天各举一例。
# 2. 为什么预测前通常要先训练？
# 3. 五天链条用一句话串起来。

# %%
# 在这里写
