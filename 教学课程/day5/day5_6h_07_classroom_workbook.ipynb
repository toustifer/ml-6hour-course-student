# %% [markdown]
# # Day 5 课堂练习册
#
# 证据 + 演示 + 汇报。

# %% [markdown]
# ## 练习 1：三个老板问题

# %%
# 1. 2. 3.

# %% [markdown]
# ## 练习 2：场景证据两条（带数字）

# %%
# 在这里写

# %% [markdown]
# ## 练习 3：交叉表一句结论

# %%
# 在这里写

# %% [markdown]
# ## 练习 4：重要性业务话 + R² 白话

# %%
# 在这里写

# %% [markdown]
# ## 练习 5：what-if 一组数字（基准 vs 改后）

# %%
# 在这里写

# %% [markdown]
# ## 练习 6：迷你网页启动成功打勾

# %%
# 记录：训练 R2=  MAE=  我演示时改的特征=

# %% [markdown]
# ## 练习 7：60 秒汇报草稿（含一句演示指引）

# %%
# 在这里写
