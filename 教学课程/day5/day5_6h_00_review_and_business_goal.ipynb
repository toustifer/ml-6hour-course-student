# %% [markdown]
# # Day 5 模块 0：从模型到经营 · 结营日主线
#
# 前四天你学会了：读表、做特征、训随机森林、用 R²/MAE 评估。
#
# **今天中心不是再学一个新算法，而是：**
#
# ```text
# 用数据 + 模型，回答咖啡馆「怎么更好卖」
#   → 写出能给店长听的结论
#   → 结营展示 + 五天复盘
# ```
#
# ## 今天主线
#
# ```text
# 经营问题（店长会问什么）
#   → 场景对比分析（天气/周末/促销…）
#   → 模型帮决策（重要性 + 假如…会怎样）
#   → 一页经营诊断
#   → 结营路演 + 总结
# ```
#
# | 角色 | 今天你像谁 |
# | --- | --- |
# | 前四天 | 数据分析学徒 |
# | 今天 | 给店长做简报的小顾问 |
#
# ## 可选（有余力）
#
# 文件夹里仍有 `mini_predict_app.py` 与 `system/`：把预测挂到网页。
# **主课时间优先给经营分析与结营**；网页演示由老师选做或课后自玩。

# %% [markdown]
# ## 1. 环境自检

# %%
import sys
print('Python:', sys.version.split()[0])
import pandas as pd
import sklearn
print('pandas', pd.__version__, '| sklearn', sklearn.__version__)
import matplotlib
print('matplotlib', matplotlib.__version__)
print('OK')

# %% [markdown]
# ## 2. 读入数据

# %%
from pathlib import Path
import pandas as pd

candidate_paths = [
    Path('day5_cafe_sales.csv'),
    Path('day5') / 'day5_cafe_sales.csv',
    Path('教学课程') / 'day5' / 'day5_cafe_sales.csv',
]
for path in candidate_paths:
    if path.exists():
        csv_path = path
        break
else:
    raise FileNotFoundError('未找到 day5_cafe_sales.csv')

df = pd.read_csv(csv_path)
print(csv_path.resolve())
print('shape:', df.shape)
df.head()

# %% [markdown]
# ## 3. 30 秒口头
#
# 1. 店长最关心的数字通常是什么？（提示：营收、哪些天差）
# 2. 模型的特征重要性，用业务话怎么说？
# 3. 「分析做完了」和「能给建议」差在哪里？

# %%
# 可选记录
