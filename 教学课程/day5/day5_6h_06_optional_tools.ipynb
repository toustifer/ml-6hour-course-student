# %% [markdown]
# # Day 5 模块 6：可选工具箱（非主线）
#
# 主线是经营分析与结营。以下仅在有余力或老师演示时使用。
#
# ## 1. 迷你预测网页
#
# - 文件：`mini_predict_app.py`
# - 特征与 Day 3/4 一致
# - 启动：`python mini_predict_app.py` → `http://127.0.0.1:5001`
#
# 适合：把 what-if 做成表单，给路演加一点「产品感」。
#
# ## 2. 完整演示系统
#
# - 目录：`system/`
# - 启动：`cd system` → `python app.py` → `http://127.0.0.1:5000`
# - 需要：`flask`（`conda install flask -y`）
#
# 适合：看「数据-训练-预测」产品长什么样；**不要求会写前端**。
#
# ## 3. 和 AI 工具一起做经营分析（建议用法）
#
# ```text
# 好提问 = 目标 + 数据情况 + 已有结果 + 请输出「发现/建议/局限」
# ```
#
# 验收标准：数字能在你自己的 notebook 里对上；建议你自己改成店长语言。
#
# ## 4. 小练习（可选）
#
# 用 AI 润色你的一页纸，但保留你算出的原始数字；对比润色前后，删掉任何你看不懂的句子。

# %%
# 可选笔记
