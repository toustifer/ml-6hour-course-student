# %% [markdown]
# # Day 5 模块 6：结课整合与扩展
#
# ## 1. 五天你搭出了什么
#
# ```text
# 数据（CSV）
#   → 分析与特征（Day 1–2）
#   → 模型（Day 3 树/森林）
#   → 评估与调参（Day 4）
#   → Web 产品（Day 5 Flask）
# ```
#
# 咖啡馆案例只是载体；同样的链路可以换成：成绩预测、销量、能耗……
#
# ## 2. 今天你应能独立做到
#
# 1. 启动 `mini_predict_app.py` 或 `system/app.py`
# 2. 在浏览器完成一次训练 + 一次预测
# 3. 用人话说明：按钮 → 路由 → 模型 → JSON → 页面
# 4. 指出 R² / 特征重要性在系统里出现的位置
#
# ## 3. 扩展思路（了解即可）
#
# | 方向 | 例子 |
# | --- | --- |
# | 数据大了 | 数据库，而不是每次读整个 CSV |
# | 模型更强 | 换算法、更多特征、定期重训 |
# | 上线 | 云服务器、域名、进程守护（gunicorn 等） |
# | 多用户 | 登录、每人自己的数据 |
# | 体验 | 更好的表单校验、错误提示、权限 |
#
# ## 4. 五天自检（口头或写关键词）

# %%
checklist = [
    '会用变量/列表/if/for 读 CSV',
    '会筛选、分组、构造简单特征',
    '会 train_test_split + 随机森林 fit',
    '会读测试 R² / MAE，知道过拟合苗头',
    '会看 feature_importances_',
    '能启动 Flask 并完成训练+预测',
]
for i, item in enumerate(checklist, 1):
    print(f'{i}. [ ] {item}')
print('\n请在纸上或下一格给自己打勾')

# %%
# 我已经会的 / 还要复习的：

# %% [markdown]
# ## 5. 结束语
#
# 机器学习不只是「调一个库」，而是：
#
# **问题 → 数据 → 特征 → 模型 → 评估 → 用起来（系统）**。
#
# 今天你把最后一环接上了。课后把迷你应用再独立启动一遍，就是最好的复习。
