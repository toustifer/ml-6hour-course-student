# %% [markdown]
# # Day 5 课后 / 结营提交说明
#
# 若营期要求提交，以老师当天通知为准。以下为推荐交付。

# %% [markdown]
# ## 任务 1 · 一页经营诊断
#
# 按模块 4 模板完成（可 Word / Markdown / notebook 导出）。
# 必须含：整体数字、≥2 条场景发现、模型或 what-if 之一、3 条建议、1 条局限。

# %%
# 可在此生成数字附件

# %% [markdown]
# ## 任务 2 · 路演稿
#
# 3～5 分钟口述稿提纲（不必全文）。

# %%
# 提纲

# %% [markdown]
# ## 任务 3 · 五天复盘
#
# 每人 8～12 句：每天学会了什么；哪一步最有成就感；还想继续学什么。

# %%
# 复盘

# %% [markdown]
# ## 任务 4（可选）
#
# 启动迷你网页，截一张预测界面，说明它对应你报告里的哪条 what-if。

# %%
# 可选
