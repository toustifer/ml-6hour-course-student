# %% [markdown]
# # Day 5 课后 / 结营提交
#
# 以老师当天通知为准。推荐交付如下。

# %% [markdown]
# ## 任务 1 · 汇报卡 + 证据附件
#
# 模块 5 汇报卡填完整；附场景数字与 what-if 数字（截图或 notebook 导出均可）。

# %%
# 数字附件

# %% [markdown]
# ## 任务 2 · 演示说明
#
# 说明你如何启动迷你网页；写 4 步「给老板点哪里」。
# 若环境无法装 Flask，写清替代：notebook what-if 演示步骤。

# %%
# 4 步演示

# %% [markdown]
# ## 任务 3 · 五天复盘
#
# 8～12 句：每天学会什么；哪一步最有成就感；还想继续什么。

# %%
# 复盘

# %% [markdown]
# ## 任务 4（可选）
#
# 启动 `system/` 完整版，对比迷你版：多了什么页面？路演时你更推荐用哪个？为什么？

# %%
# 可选
