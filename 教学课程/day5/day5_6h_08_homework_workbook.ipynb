# %% [markdown]
# # Day 5 课后练习册
#
# 在自己电脑上独立完成。需已安装 `flask` 与 `day1_ml` 环境。

# %% [markdown]
# ## 任务 1
#
# 启动 `mini_predict_app.py`，完成训练 + 至少 **2 组**不同特征的预测，把输入和预测值记下来。

# %%
# 任务 1

# %% [markdown]
# ## 任务 2
#
# 用 notebook 或浏览器开发者工具以外的方式：对 `http://127.0.0.1:5001/api/hello` 或 train/predict 发一次请求，粘贴返回 JSON。

# %%
# 任务 2

# %% [markdown]
# ## 任务 3（读代码）
#
# 阅读 `mini_predict_app.py`，回答：
#
# 1. `FEATURE_COLS` 有哪些？
# 2. `ensure_model` 里 `random_state` 是多少？
# 3. 预测接口若模型不在缓存会怎样？

# %%
# 任务 3

# %% [markdown]
# ## 任务 4（可选挑战）
#
# 改迷你应用：训练成功后在页面上多显示一行「模型已就绪」。
# （改 HTML 字符串或 `trainInfo` 拼接即可）

# %%
# 任务 4 说明你改了哪里

# %% [markdown]
# ## 任务 5（文字）
#
# 写 8–12 句结课小结：五天分别学了什么；系统里你最有成就感的一步；还想继续学什么。

# %%
# 任务 5
