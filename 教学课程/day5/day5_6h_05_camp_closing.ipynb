# %% [markdown]
# # Day 5 模块 5：结营路演与五天收束
#
# ## 1. 路演怎么讲（3～5 分钟）
#
# ```text
# 1. 我是谁、店叫什么（设定 10 秒）
# 2. 我回答了哪 2～3 个经营问题
# 3. 最硬的 2 个数字证据（场景或模型）
# 4. 3 条建议 + 如何验证
# 5. 我学到的一步（技术或思维）
# ```
#
# 不要念代码。代码是证据后台，前台是结论。

# %% [markdown]
# ## 2. 路演卡片（填写）

# %%
# 路演卡片
# 经营问题：
# 证据 1：
# 证据 2：
# 建议：
# 一句话收获：

# %% [markdown]
# ## 3. 五天链条（结营必背）
#
# ```text
# Day1  Python 与数据感觉
# Day2  把表切出经营场景
# Day3  决策树 / 随机森林：从特征猜营收
# Day4  评估、对比、调参、残差
# Day5  经营诊断 + 建议 + 结营表达
# ```
#
# 技术栈是手段；**把数据变成可执行建议**才是今天的终点。

# %% [markdown]
# ## 4. 自我合格线（打勾）
#
# 1. 能独立跑场景对比（至少天气或促销）
# 2. 能训 RF 并说出 Top 重要性（业务话）
# 3. 能做一次 what-if 或会读别人的 what-if
# 4. 有一页诊断 + 能路演 3 分钟
# 5. 能用一句话串起五天

# %%
items = [
    '场景对比',
    '重要性业务话',
    'what-if',
    '一页诊断',
    '五天一句话',
]
for i, t in enumerate(items, 1):
    print(f'{i}. [ ] {t}')

# %% [markdown]
# ## 5. 可选：网页演示
#
# 若老师安排或你有兴趣：
#
# ```text
# cd 教学课程/day5
# python mini_predict_app.py
# # 浏览器 http://127.0.0.1:5001
# ```
#
# 把 what-if 从 notebook「点成按钮」——仍然服务于经营故事，不是另开一门 Web 课。

# %% [markdown]
# ## 6. 结营寄语（读一下即可）
#
# 你带走的不只是几个函数名，而是一条可迁移的工作流：
#
# **提问 → 取证 → 模型辅助 → 建议 → 验证**。
#
# 换一个行业，链条同样用得上。祝贺完成本次营期。
