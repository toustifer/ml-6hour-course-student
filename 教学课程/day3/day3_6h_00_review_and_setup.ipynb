# %% [markdown]
# # Day 3 模块 0：复习与环境自检
#
# 今天会开始训练模型。先确认：数据还在，pandas 还在，sklearn 也能用。

# %% [markdown]
# ## 1. 先回顾 Day 1 / Day 2
#
# 我们已经会：
#
# - 读 CSV、看表
# - 选列、过滤、排序、groupby
# - 构造简单新列
# - 知道训练集 / 测试集为什么要分开

# %% [markdown]
# ## 2. 读入今天的数据

# %%
from pathlib import Path
import pandas as pd

candidate_paths = [
    Path('day3_cafe_sales.csv'),
    Path('day3') / 'day3_cafe_sales.csv',
    Path('教学课程') / 'day3' / 'day3_cafe_sales.csv',
]
for path in candidate_paths:
    if path.exists():
        csv_path = path
        break
else:
    raise FileNotFoundError('未找到 day3_cafe_sales.csv')

df = pd.read_csv(csv_path)
print(csv_path.resolve())
print('shape:', df.shape)
df.head()
# Out:
# D:\obi\熵学院\授课\机器学习-6小时\教学课程\day3\day3_cafe_sales.csv
# shape: (200, 12)
#    day  weather weather_label  temp  is_weekend  promotion  quality  price  \
# 0    1        1            多云  33.5           0          1     8.27   24.5
# 1    2        2             阴   6.7           0          1     9.57   22.0
# 2    3        0             晴  23.4           0          0     7.11   27.9
# 3    4        2             阴   6.4           0          0     6.65   23.0
# 4    5        0             晴  11.9           0          0     8.60   31.8
#
#    location  competitors  holiday  sales
# 0      5.78            2        0   3249
# 1      9.96            0        0   4700
# 2      7.28            5        0   2071
# 3      9.74            3        0   2370
# 4      9.17            2        0   2847

# %% [markdown]
# ## 3. 检查 sklearn 是否可用
#
# 如果这里报错，先告诉老师，不要自己乱换环境。

# %%
import sklearn
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

print('sklearn', sklearn.__version__)
print('模型相关模块导入成功')
# Out:
# sklearn 1.7.2
# 模型相关模块导入成功

# %% [markdown]
# ## 4. 快速复习：天气平均营收

# %%
df.groupby('weather_label')['sales'].mean().round(2)
# Out:
# weather_label
# 多云    2828.88
# 大雨    2345.62
# 小雨    2439.70
# 晴     2940.89
# 阴     2623.05
# Name: sales, dtype: float64
