# %% [markdown]
# # Day 3 课后练习册
#
# 请尽量独立完成。不会的地方先回看对应模块。

# %% [markdown]
# ## 任务 1
#
# 读入 `day3_cafe_sales.csv`，查看前 5 行和列名。

# %%
# 在这里写

# %% [markdown]
# ## 任务 2
#
# 构造 `weather_score`，准备 `X` 与 `y=sales`，并划分训练/测试集。

# %%
# 在这里写

# %% [markdown]
# ## 任务 3
#
# 训练一棵 `max_depth=3` 的决策树，记录测试集 R²。

# %%
# 在这里写

# %% [markdown]
# ## 任务 4
#
# 训练随机森林（可用 `n_estimators=100`），记录训练/测试 R²。

# %%
# 在这里写

# %% [markdown]
# ## 任务 5
#
# 输出特征重要性排序，并写一句业务观察。

# %%
# 在这里写

# %% [markdown]
# ## 任务 6
#
# 构造至少 2 组“新的一天”特征，分别预测营收，并比较差异。

# %%
# 在这里写

# %% [markdown]
# ## 任务 7（文字）
#
# 用自己的话解释：随机森林为什么通常比单棵决策树更稳？

# %%
# 在这里写

# %% [markdown]
# ## 任务 8（了解即可）
#
# 如果测试集 R² 比训练集低很多，可能意味着什么？

# %%
# 在这里写
