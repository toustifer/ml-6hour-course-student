# %% [markdown]
# # Day 3 课堂练习册
#
# 这本不是新课，是跟着模块 2–6 做巩固。

# %% [markdown]
# ## 练习 1：准备 X 和 y
#
# 读入数据，构造 `weather_score`，准备特征矩阵 `X` 和目标 `y`。

# %%
# 在这里写

# %% [markdown]
# ## 练习 2：划分数据
#
# 用 `train_test_split` 划分，测试集比例 0.2，`random_state=42`。

# %%
# 在这里写

# %% [markdown]
# ## 练习 3：训练决策树
#
# 训练 `max_depth=3` 的决策树，打印测试集 R²。

# %%
# 在这里写

# %% [markdown]
# ## 练习 4：训练随机森林
#
# 训练 `RandomForestRegressor`，打印训练/测试 R²。

# %%
# 在这里写

# %% [markdown]
# ## 练习 5：特征重要性
#
# 输出按重要性从高到低排序的表。

# %%
# 在这里写

# %% [markdown]
# ## 练习 6：预测新一天
#
# 自己给一组特征，调用 `predict`，写出预测营收。

# %%
# 在这里写
