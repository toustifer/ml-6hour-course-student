# %% [markdown]
# # Day 1 模块 0：环境安装与工具入门
#
# 这一模块**先不学数据分析**。
#
# 先把上课要用的工具装好、跑通。
#
# 今天会认识并安装：
#
# 1. **Python**：真正执行代码的语言
# 2. **Jupyter Notebook**：写代码、看结果的课堂主工具
# 3. **VS Code**：打开 notebook、改文件的编辑器
# 4. **conda（Miniconda / Anaconda）**：管理 Python 环境和数据包的工具
# 5. **常用数据包**：`pandas`、`matplotlib`
#
# 装好之后，后面所有模块才可以顺利运行。
#
# > 本说明默认你用的是 **Windows 电脑**。
# > Mac 同学请看同目录下的 `day1_6h_00_env_setup_and_tools_mac.ipynb`。

# %% [markdown]
# ## 1. 先搞清楚这些工具分别干什么
#
# | 工具 | 一句话理解 | 上课时主要用来做什么 |
# | --- | --- | --- |
# | Python | 会“算”的语言 | 运行我们写的代码 |
# | Jupyter Notebook | 一格一格写代码的本子 | 上课主界面：写、运行、看输出 |
# | VS Code | 写文件的编辑器 | 打开 `.ipynb`、看文件夹、装扩展 |
# | **conda** | 环境与包的“管家” | 安装 Python、创建独立环境、装 `pandas` 等包 |
# | pip | 另一种装包方式 | 在已有 Python 里装包（路线 A 常用） |
#
# 可以这样记：
#
# - **Python** = 发动机
# - **Jupyter** = 方向盘和仪表盘
# - **VS Code** = 车库和工作台
# - **conda** = 帮你把发动机、零件、油箱都管整齐的仓库管理员
#
# 它们不是互相替代，而是一起用。

# %% [markdown]
# ## 2. 两条安装路线（二选一）
#
# 课堂里**只走一条线**，不要两条混装很多份 Python。
#
# ### 路线 A：官方 Python + pip（轻量）
#
# ```
# 安装 Python（官网）
#    ↓
# 安装 VS Code + Python/Jupyter 扩展
#    ↓
# pip 安装 pandas / matplotlib
#    ↓
# 打开 notebook，运行第一个 print
# ```
#
# ### 路线 B：conda（Miniconda / Anaconda）（机房统一装时推荐）
#
# ```
# 安装 Miniconda 或 Anaconda
#    ↓
# 打开 Anaconda Prompt（或 Miniconda Prompt）
#    ↓
# 创建课程环境 day1_ml，装 pandas / matplotlib / jupyter
#    ↓
# 安装 VS Code + Python/Jupyter 扩展
#    ↓
# 打开 notebook，选择 conda 环境对应的内核
#    ↓
# 运行第一个 print
# ```
#
# **怎么选？**
#
# | 情况 | 建议 |
# | --- | --- |
# | 自己笔记本、想装得轻一点 | 路线 A |
# | 学校机房、老师统一发环境、以后还要装很多科学计算包 | **路线 B（conda）** |
# | 已经装好其中一条，且能 `import pandas` | 不要再重装另一条 |
#
# 如果学校已经统一装好，就跳过安装，直接做后面的“环境自检”。

# %% [markdown]
# ## 3. 路线 A：安装官方 Python
#
# ### 3.1 去哪里下载
#
# 官方下载页：
#
# - https://www.python.org/downloads/
#
# 建议安装 **Python 3.10 或更高**（3.11 / 3.12 都可以）。
#
# ### 3.2 Windows 安装时最关键的一步
#
# 安装界面下方有一个勾选项：
#
# > **Add python.exe to PATH**
#
# **一定要勾上。**
#
# 不勾的话，后面终端里输入 `python` 经常会找不到。
#
# 然后点 `Install Now`，等它装完。
#
# ### 3.3 怎么确认 Python 装好了
#
# 1. 按键盘 `Win` 键
# 2. 输入 `cmd`，打开“命令提示符”
#    - 或者输入 `powershell`，打开 PowerShell
# 3. 输入下面两行，每行输完按回车：
#
# ```text
# python --version
# pip --version
# ```
#
# 看到类似结果就说明成功了：
#
# ```text
# Python 3.12.x
# pip 24.x from ...
# ```
#
# 如果提示“不是内部或外部命令”：
#
# - 多半是安装时没勾 `Add to PATH`
# - 解决办法：卸载重装，并勾上 PATH；或请老师帮你把 Python 加入环境变量
#
# > 如果你选的是**路线 B（conda）**，可以跳过本节，直接看第 4 节。

# %% [markdown]
# ## 4. 路线 B：安装 conda（Miniconda / Anaconda）
#
# ### 4.1 conda 是什么？
#
# **conda** 是一个**环境管理 + 包管理**工具。
#
# 一句话：
#
# - 可以装 Python
# - 可以给不同课程建“独立房间”（环境），互不打架
# - 可以在房间里安装 `pandas`、`matplotlib` 等包
#
# 为什么课堂常用它？
#
# - 避免“我电脑上有三个 Python，装包装错地方”
# - 老师可以说：“大家一起用 `day1_ml` 这个环境”
# - 以后 Day 2～5 再加包，也装进同一个环境即可
#
# ### 4.2 Miniconda 还是 Anaconda？
#
# | 产品 | 特点 | 课堂建议 |
# | --- | --- | --- |
# | **Miniconda** | 体积小，只带 conda + 基础 Python，包自己装 | **更推荐**（快、干净） |
# | **Anaconda** | 体积大，自带很多数据科学包 | 机房网速慢、想少敲命令时可用 |
#
# 两者都提供 `conda` 命令，**用法一样**。本课程命令以 conda 为准。
#
# ### 4.3 下载地址
#
# - Miniconda：https://docs.conda.io/en/latest/miniconda.html
#   （选 Windows 64-bit 安装包）
# - Anaconda：https://www.anaconda.com/download
#
# ### 4.4 Windows 安装注意
#
# 1. 安装路径建议用默认（不要装到带中文、空格很多的奇怪路径）
# 2. 若出现选项：
#    - **Add Miniconda3 to my PATH environment variable**
#      新手可勾上（方便在普通终端用 `conda`）
#      若不勾，就**只用 “Anaconda Prompt / Miniconda Prompt”** 输入命令
# 3. 装完后，从开始菜单打开：
#    - **Anaconda Prompt**，或
#    - **Miniconda Prompt**（Miniconda 用户）
#
# 后面所有 conda 命令，都在这个 Prompt 里输入最稳。
#
# ### 4.5 确认 conda 装好了
#
# 在 Anaconda / Miniconda Prompt 中输入：
#
# ```text
# conda --version
# python --version
# ```
#
# 看到版本号即可，例如：
#
# ```text
# conda 24.x.x
# Python 3.12.x
# ```

# %% [markdown]
# ## 5. 用 conda 创建课程环境（核心步骤）
#
# 装完 conda 后，**不要直接在 base 里乱装一堆包**（可以，但不推荐）。
#
# 更好的习惯：为这门课建一个独立环境，名字叫 `day1_ml`。
#
# ### 5.1 创建环境并装上课包
#
# 在 Anaconda / Miniconda Prompt 中**逐行**输入：
#
# ```text
# conda create -n day1_ml python=3.11 -y
# conda activate day1_ml
# conda install pandas matplotlib jupyter -y
# ```
#
# 含义：
#
# | 命令 | 意思 |
# | --- | --- |
# | `conda create -n day1_ml python=3.11` | 新建名为 `day1_ml` 的环境，Python 版本 3.11 |
# | `conda activate day1_ml` | 进入这个环境（提示符前会出现 `(day1_ml)`） |
# | `conda install pandas matplotlib jupyter -y` | 在环境里安装上课要用的包 |
#
# 如果 `conda install` 很慢，可以先配置清华镜像（可选）：
#
# ```text
# conda config --add channels https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
# conda config --add channels https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/free
# conda config --set show_channel_urls yes
# ```
#
# 然后再执行 `conda install ...`。
#
# ### 5.2 确认环境里的包
#
# 环境激活后（提示符有 `(day1_ml)`）：
#
# ```text
# conda list pandas
# python -c "import pandas, matplotlib; print('ok')"
# ```
#
# 输出 `ok` 就说明环境可用。
#
# ### 5.3 每次上课怎么进入环境？
#
# 1. 打开 **Anaconda Prompt / Miniconda Prompt**
# 2. 输入：
#
# ```text
# conda activate day1_ml
# ```
#
# 3. 再打开 VS Code，或在 VS Code 里选择 `day1_ml` 对应的 Python 内核
#
# ### 5.4 conda 和 pip 的关系（先记住这三句）
#
# 1. **优先用 conda 装**：`conda install 包名`
# 2. conda 没有的包，再在**已 activate 的环境里**用：`pip install 包名`
# 3. 不要在没 activate 的情况下到处 `pip install`，否则包会装错 Python
#
# 本课 Day 1 只需要：`pandas`、`matplotlib`、`jupyter`，用 conda 就够。

# %% [markdown]
# ## 6. 安装 VS Code（两条路线都要）
#
# ### 6.1 下载
#
# - https://code.visualstudio.com/
#
# 选择 Windows 版本，下载安装包，一路“下一步”即可。
#
# ### 6.2 安装时建议勾选
#
# - 创建桌面图标
# - 通过“打开方式”用 Code 打开文件
# - 添加到 PATH（如果有这个选项）
#
# ### 6.3 打开后先装两个扩展
#
# 打开 VS Code 左侧扩展市场（四个小方块图标），搜索并安装：
#
# 1. **Python**（发布者：Microsoft）
# 2. **Jupyter**（发布者：Microsoft）
#
# 这两个装好后，`.ipynb` 文件才能正常运行。
#
# ### 6.4 用 VS Code 打开课程文件夹
#
# 1. 打开 VS Code
# 2. 点 `文件` → `打开文件夹...`
# 3. 选中课程的 `day1` 文件夹
# 4. 左侧应能看到这些文件，例如：
#    - `day1_6h_00_env_setup_and_tools.ipynb`（当前这本）
#    - `day1_6h_01_course_and_data_concepts.ipynb`
#    - `day1_cafe_sales.csv`
#
# ### 6.5 选对内核（非常重要）
#
# 打开本 notebook 后，点右上角 **选择内核 / Select Kernel**：
#
# - 路线 A：选你安装的 **Python 3.x**
# - 路线 B：选带 **`day1_ml`** 字样的解释器
#   （例如 `Python 3.11.x ('day1_ml': conda)`）
#
# 如果列表里没有 `day1_ml`：
#
# 1. 先在 Anaconda Prompt 里 `conda activate day1_ml`
# 2. 在 VS Code 命令面板（`Ctrl+Shift+P`）搜 `Python: Select Interpreter`
# 3. 选 `day1_ml`，再回到 notebook 选内核

# %% [markdown]
# ## 7. Jupyter 是什么？怎么在 VS Code 里用？
#
# Jupyter Notebook 的文件后缀是：
#
# ```text
# .ipynb
# ```
#
# 它由很多“格子”组成：
#
# - **Markdown 格子**：写文字说明
# - **Code 格子**：写 Python 代码
#
# 运行一个代码格子：
#
# 1. 鼠标点进这个格子
# 2. 按 `Shift + Enter`
#
# 第一次运行时，VS Code 可能会问你：
#
# > 选择内核（Select Kernel）
#
# - 路线 A：选官方 Python 3.x
# - 路线 B：选 **day1_ml** 环境
#
# 选对内核后，格子左边会出现运行结果。

# %% [markdown]
# ## 8. 路线 A 补充：用 pip 安装上课包
#
# > 只有走**路线 A（官方 Python）**时需要本节。
# > 路线 B 已在第 5 节用 `conda install` 装过，可跳过。
#
# Day 1 主要会用到：
#
# - `pandas`：读表格、做统计
# - `matplotlib`：画图
#
# 在 VS Code 终端里输入（`终端` → `新建终端`）：
#
# ```text
# python -m pip install -U pip
# python -m pip install pandas matplotlib jupyter
# ```
#
# 如果学校网络较慢，可以用国内镜像：
#
# ```text
# python -m pip install -U pip -i https://pypi.tuna.tsinghua.edu.cn/simple
# python -m pip install pandas matplotlib jupyter -i https://pypi.tuna.tsinghua.edu.cn/simple
# ```
#
# 确认：
#
# ```text
# python -c "import pandas, matplotlib; print('ok')"
# ```

# %% [markdown]
# ## 9. 第一次运行代码（环境自检）
#
# 下面这些格子，装好环境后按顺序运行。
#
# 只要都能跑通，环境就基本就绪。
#
# > 运行前请确认右上角内核正确（路线 B 应是 `day1_ml`）。

# %% [markdown]
# ### 9.1 检查 Python 能不能输出

# %%
print('你好，环境安装成功')
print('下一步可以开始 Day 1 正式内容')

# %% [markdown]
# ### 9.2 检查 Python 版本与是否在 conda 环境中

# %%
import sys
import os

print('Python 版本:', sys.version)
print('Python 路径:', sys.executable)

# 如果用了 conda，通常能看到环境名
conda_env = os.environ.get('CONDA_DEFAULT_ENV')
if conda_env:
    print('当前 conda 环境:', conda_env)
else:
    print('当前未检测到 conda 环境名（可能是路线 A：官方 Python + pip）')

# %% [markdown]
# ### 9.3 检查 pandas / matplotlib 是否能导入

# %%
import pandas as pd
import matplotlib

print('pandas 版本:', pd.__version__)
print('matplotlib 版本:', matplotlib.__version__)
print('数据包导入成功')

# %% [markdown]
# ### 9.4 检查课程数据文件是否在旁边

# %%
from pathlib import Path

candidate_paths = [
    Path('day1_cafe_sales.csv'),
    Path('day1') / 'day1_cafe_sales.csv',
    Path('教学课程') / 'day1' / 'day1_cafe_sales.csv',
]

csv_path = None
for path in candidate_paths:
    if path.exists():
        csv_path = path
        break

if csv_path is None:
    print('还没找到 day1_cafe_sales.csv')
    print('请确认 VS Code 打开的是 day1 文件夹')
else:
    print('找到数据文件:', csv_path.resolve())

# %% [markdown]
# ### 9.5 可选：试着读入一行数据
#
# 如果上一格已经找到 CSV，再运行这一格。

# %%
import pandas as pd
from pathlib import Path

candidate_paths = [
    Path('day1_cafe_sales.csv'),
    Path('day1') / 'day1_cafe_sales.csv',
    Path('教学课程') / 'day1' / 'day1_cafe_sales.csv',
]

for path in candidate_paths:
    if path.exists():
        df = pd.read_csv(path)
        print('读取成功，形状:', df.shape)
        print(df.head(3))
        break
else:
    print('未找到数据文件，先回到上一格检查路径')

# %% [markdown]
# ## 10. 课堂常用操作速查
#
# | 你想做的事 | 怎么做 |
# | --- | --- |
# | 运行当前代码格 | `Shift + Enter` |
# | 只运行不跳到下一格 | `Ctrl + Enter` |
# | 选择 Python / conda 内核 | 点 notebook 右上角 `选择内核` |
# | 打开终端 | VS Code 菜单：`终端` → `新建终端` |
# | 进入 conda 环境 | Anaconda Prompt 中：`conda activate day1_ml` |
# | 用 conda 装包 | `conda activate day1_ml` 后：`conda install 包名 -y` |
# | 用 pip 装包（路线 A） | `python -m pip install 包名` |
# | 看 Python 版本 | `python --version` |
# | 看 conda 版本 | `conda --version` |
# | 列出已有环境 | `conda env list` |
# | 重新打开文件夹 | `文件` → `打开文件夹...` |

# %% [markdown]
# ## 11. 常见报错与处理
#
# ### 11.1 `python` / `conda` 不是内部或外部命令
#
# - 原因：没装好，或没加入 PATH，或不在 Anaconda Prompt 里
# - 处理：
#   - 路线 A：重装 Python，勾选 `Add python.exe to PATH`
#   - 路线 B：从开始菜单打开 **Anaconda Prompt / Miniconda Prompt** 再输入命令
#
# ### 11.2 `No module named 'pandas'`
#
# - 原因：包还没装，或装到了另一个 Python / 另一个 conda 环境里
# - 处理：
#   - 路线 A：`python -m pip install pandas matplotlib`
#   - 路线 B：先 `conda activate day1_ml`，再 `conda install pandas matplotlib -y`
#   - 然后在 notebook 右上角**重新选择**同一个环境的内核
#
# ### 11.3 notebook 选不到 `day1_ml`
#
# - 先确认环境存在：`conda env list` 里应有 `day1_ml`
# - VS Code 已装 Python + Jupyter 扩展
# - `Ctrl+Shift+P` → `Python: Select Interpreter` → 选 `day1_ml`
# - 仍没有：重启 VS Code 再试
#
# ### 11.4 `conda activate` 失败（PowerShell 报错）
#
# - 最省事：改用 **Anaconda Prompt**，不要用未初始化的 PowerShell
# - 或在 Anaconda Prompt 里完成 `activate` 和装包，只把 VS Code 当编辑器
#
# ### 11.5 运行格子没有反应 / 一直转圈
#
# - 先看右上角是否已经选中内核
# - 点 `重启` 后再运行一次
# - 确认装的是 Python 扩展 + Jupyter 扩展
#
# ### 11.6 找不到 `day1_cafe_sales.csv`
#
# - 原因：VS Code 打开的不是 `day1` 文件夹
# - 处理：重新 `打开文件夹`，选到包含 CSV 和 notebook 的那个目录
#
# ### 11.7 画图中文乱码
#
# - Day 1 后面模块会设置中文字体
# - 先保证代码能跑；字体问题后面再统一处理
#
# ### 11.8 同时装了官方 Python 和 conda，更乱了
#
# - 上课时**固定用一种**：老师说用 conda，就只用 `day1_ml` 内核
# - 看 `sys.executable` 打印的路径，确认自己跑的是哪一份 Python

# %% [markdown]
# ## 12. 装完后的检查清单
#
# 全部打勾再进入模块 1：
#
# **通用**
#
# - [ ] VS Code 已安装
# - [ ] VS Code 已装 Python 扩展
# - [ ] VS Code 已装 Jupyter 扩展
# - [ ] 已打开 `day1` 文件夹
# - [ ] 本 notebook 能运行 `print(...)`
# - [ ] `import pandas` 成功
# - [ ] `import matplotlib` 成功
# - [ ] 能找到 `day1_cafe_sales.csv`
# - [ ] 右上角内核选对了
#
# **若走路线 A**
#
# - [ ] `python --version` 能显示版本
# - [ ] `pip --version` 能显示版本
#
# **若走路线 B（conda）**
#
# - [ ] `conda --version` 能显示版本
# - [ ] `conda env list` 能看到 `day1_ml`
# - [ ] 已执行过 `conda activate day1_ml`
# - [ ] notebook 内核显示为 `day1_ml`（或同等 conda 环境）
#
# 如果上面都通过，环境就就绪了。

# %% [markdown]
# ## 13. 模块小结
#
# 记住这几件事：
#
# 1. **Python** 负责执行代码
# 2. **VS Code** 负责打开文件和写 notebook
# 3. **Jupyter** 让我们一格一格运行代码
# 4. **conda** 负责管理环境和安装包（路线 B）
# 5. **pip** 也可以装包（路线 A，或 conda 环境内补装）
# 6. 运行代码最常用快捷键是 `Shift + Enter`
# 7. **内核选错 = 包找不到**，出问题先看右上角
#
# conda 上课最小命令集：
#
# ```text
# conda create -n day1_ml python=3.11 -y
# conda activate day1_ml
# conda install pandas matplotlib jupyter -y
# conda env list
# ```
#
# 下一模块：
#
# - `day1_6h_01_course_and_data_concepts.ipynb`
# - 先认识数据表（还不写复杂代码）
