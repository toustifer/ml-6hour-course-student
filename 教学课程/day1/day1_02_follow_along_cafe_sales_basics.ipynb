# %% [markdown]
# # Day 1 课堂跟练版：咖啡馆营收数据入门
#
# 这份 notebook 是**压缩跟练版**。
#
# **零基础正式主线请优先使用模块版 `day1_6h_01` ~ `06`。**
#
# 本文件按同样顺序串讲：概念 → Python → 读表 → 统计 → 画图。

# %% [markdown]
# ## 0. Day 1 总流程
#
# ![Day 1 总流程图](day1_flow_overview_demo.png)

# %% [markdown]
# ## 1. 先认识数据表（不写代码）
#
# ![Excel 风格数据表示意图](day1_excel_style_table_demo_cn.png)
#
# 先口头回答：
#
# 1. 第 1 行代表什么？
# 2. `sales` 列代表什么？
# 3. 行和列哪个表示“某一天”？

# %% [markdown]
# ## 2. Python 零基础
#
# 先运行下面这个格子，确认 notebook 会动。

# %%
print('你好，Python')

# %% [markdown]
# ### 练习 A：变量
#
# 定义三个变量并打印：天气文字、营收数字、价格数字。

# %%
my_weather = '多云'
my_sales = 2800
my_price = 27.0

print(my_weather)
print(my_sales)
print(my_price)

# %% [markdown]
# ### 练习 B：列表 + for + if
#
# 遍历营收列表，大于等于 3000 打印“较高”，否则打印“一般”。

# %%
sales_list = [2400, 3100, 2900, 3600]

for item in sales_list:
    if item >= 3000:
        print(item, '较高')
    else:
        print(item, '一般')

# %% [markdown]
# ## 3. 读取 CSV
#
# ![CSV 到 DataFrame 示意图](day1_csv_to_dataframe_demo.png)

# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei', 'SimHei', 'Arial Unicode MS', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

candidate_paths = [
    Path('day1_cafe_sales.csv'),
    Path('day1') / 'day1_cafe_sales.csv',
    Path('教学课程') / 'day1' / 'day1_cafe_sales.csv',
]

for path in candidate_paths:
    if path.exists():
        csv_path = path
        break
else:
    raise FileNotFoundError('未找到 day1_cafe_sales.csv，请确认它和 notebook 位于教学课程/day1 目录。')

df = pd.read_csv(csv_path)
print('数据文件位置:', csv_path.resolve())
print('数据表形状:', df.shape)
df.head()

# %% [markdown]
# ## 4. 看懂表
#
# ![看懂数据表的四个常用工具](day1_table_tools_overview_demo.png)

# %%
print('形状:', df.shape)
print('列名:', df.columns.tolist())
df.info()
df.describe().round(2)

# %% [markdown]
# ## 5. 基础统计
#
# 输出总天数、平均营收、最高营收、最低营收。

# %%
print('总天数:', len(df))
print('平均营收:', round(df['sales'].mean(), 2))
print('最高营收:', int(df['sales'].max()))
print('最低营收:', int(df['sales'].min()))

# %% [markdown]
# ## 6. groupby
#
# ![groupby 分组统计示意图](day1_groupby_explained_demo.png)

# %%
weather_order = ['晴', '多云', '阴', '小雨', '大雨']
avg_sales_by_weather = df.groupby('weather_label')['sales'].mean().reindex(weather_order).round(2)
avg_sales_by_weather

# %% [markdown]
# ## 7. 画图
#
# ![折线图 vs 柱状图](day1_line_vs_bar_chart_demo.png)

# %%
plt.figure(figsize=(12, 4))
plt.plot(df['day'], df['sales'], color='#6f4e37', linewidth=1.8)
plt.title('每日营收趋势')
plt.xlabel('Day')
plt.ylabel('Sales')
plt.grid(alpha=0.25)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 4))
avg_sales_by_weather.plot(kind='bar', color='#c89b74')
plt.title('不同天气下的平均营收')
plt.xlabel('天气')
plt.ylabel('平均营收')
plt.xticks(rotation=0)
plt.grid(axis='y', alpha=0.25)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. 跟练检查点
#
# 完成下面四项再收工：
#
# - [ ] 会运行 `print`
# - [ ] 会写变量、列表、if、for
# - [ ] 会 `pd.read_csv` + `head`
# - [ ] 会 `groupby` + 两张图
